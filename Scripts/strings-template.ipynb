# %% [markdown]
# ## Understanding `print()`
#
#   - THIS SECTION IS ALL ABOUT PRINTING

# %%
# hello world
print("hello world")
print('hello wolrd')

# %% [markdown]
# ### Printing quotation marks
#
# ##### Write two print statements that give the following output:
#
# She said, 'hello world'
#
# She said, "hello world"

# %%
print("She said, 'hello world'")
print('She said, "hello world"')
print("She said, \"hello world\"")
# Out:
# She said, 'hello world'
# She said, "hello world"
# She said, "hello world"

# %% [markdown]
# ### Store and print a variable

# %%
# define some strings
first = 'bob'
last = 'dylan'

# concatenate those strings
full = first + last

# print the strings
print(first)
print(last)
print(full)
print(first + last + "first")
print(first + ' ' + last + ' is the queen')
# Out:
# bob
# dylan
# bobdylan
# bobdylanfirst
# bob dylan is the queen

# %% [markdown]
# ### Get the length of a string

# %%
# the long (but readable) way
name_length = len(full)
print(name_length)
# a more concise way to do it, functions within functions
print(len(full))
# Out:
# 8
# 8

# %% [markdown]
# ### Print strings and numbers

# %%
# print strings and integers
print("There are " + str(name_length) + " characters in Bob Dylan's name.")
print("There are", name_length, "characters in Bob Dylan's name")

# print strings

# formatted print
print(f"There are {name_length} characters in Bob Dylan's name")
# Out:
# There are 8 characters in Bob Dylan's name.
# There are 8 characters in Bob Dylan's name
# There are 8 characters in Bob Dylan's name

# %% [markdown]
# ### If x = 7 and y = "7", write two print statements that use `x` and `y` to print "77" and "14" as the output

# %%
x = 7
y = "7"

#print 77
print(str(x) + y)
#print 14
print (x + int(y))
# Out:
# 77
# 14

# %%
#Methods to change the case of a string
print(first, last)
print(first.upper())
print(last.lower())

#make the name properly cased (play with this string to make sure our algorithm is robust)
db_name = "AndY"

#Can give a literal string to 'capitalize()'
print(db_name.lower().capitalize())
#Ultimately our algorithm is: lowercase it first, then capitalize it: should work on any string this way
print("andy".capitalize())
db_name_lower = db_name.lower()
db_name_cap = db_name_lower.capitalize()
print(db_name_cap)

#Here we do it all in one statement
print(db_name.lower().capitalize())

# %% [markdown]
# ## Some operations on strings

# %% [markdown]
# ### Problem #1: Write a program that asks for the user's name and age, then prints a personalized greeting using string formatting (`.format`).
#
# For *Andy* and *32*, the output would be:
#
# Hello, Andy! You are 32 years old.

# %%
# code here
name = input("Enter your name: ")
age = input("Enter your age: ")

name = name.lower().capitalize()
print('Hello, {}. You are {} years old'.format(name, age))

print('Hello, {}. You are {} years old'.format(name.lower().capitalize(), age))

print(f"Hello, {name}! You are {age} years old.")
# Out:
# Hello, Luke. You are 23 years old
# Hello, Luke. You are 23 years old
# Hello, Luke! You are 23 years old.

# %% [markdown]
# ### Problem #2: Ask the user for a big number. If the user enters 1000000 (one million), the output will be:
#
# This sure is a big number: 1,000,000
#
# This sure is a big number: 1.000000e+06

# %%
big_num = input('Enter your big number here: ')
#Show that the result from input() is always a string
#print(type(big_num))

print(f'This sure is a big number: {int(big_num):,d}')
print(f'This sure is a big number: {int(big_num):e}')
print(f"This sure is a big number: {big_num}")
# Out:
# This sure is a big number: 1,000,000
# This sure is a big number: 1.000000e+06
# This sure is a big number: 1000000

# %% [markdown]
# ### Problem 3: Write a program that asks for the user's name and age, and then prints a personalized greeting using string formatting (`.format`).
#
# For **Andy** and **32**, output would be:
#
# Hello, Andy! You are 32 years old.

# %%
# problem 4 solution

# %% [markdown]
# ### Problem #4: Tip Calculator
#
# Ask the user for the bill amount (float) and tip percentage (integer). Calculate the tip and total, then print them neatly.
#
# Enter the bill amount: `42.75`
#
# Enter the tip percentage: `18`
#
# Bill: `$42.75`
#
# Tip (18%): `$7.70`
#
# \--------------------
#
# Total: `$50.45`

# %%
# problem 5 solution
Bill_Tot = input("Please provide your bill amount")
Tip_Pct = input("Please provide your tip percentage")

Bill_Tot = float(Bill_Tot)
Tip_Pct = float(Tip_Pct)
Tip_Amt = Bill_Tot*(Tip_Pct/100)
Bill = Bill_Tot + Tip_Amt
print(f'Bill: ${Bill_Tot}')
print( f'Tip ({Tip_Pct}%): ${Tip_Amt:.2f}')
print('-----------------')
print(f'Total: ${Bill:.2f} ')
# Out:
# Bill: $42.75
# Tip (18.0%): $7.69
# -----------------
# Total: $50.45
