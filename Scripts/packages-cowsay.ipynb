# %%
import cowsay

#get the list of possible characters
#format is: module.function

cowsay.char_names

cowsay.cow("Hello, World!")
# Out:
#   _____________
# | Hello, World! |
# ...
#              \
#               \
#                 ^__^
#                 (oo)\_______
#                 (__)\       )\/\
#                     ||----w |
#                     ||     ||
