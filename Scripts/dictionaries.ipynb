# %%
from collections import defaultdict

#declare some dictionaries
presidents = defaultdict(str) # key =president number, value = president name
parties = defaultdict(str) # key = president name, value = president's party

#without defaultdict, we'd declare a dictionary this way: parties = {}

#open the presidents.csv data file
input_file = "../Data/presidents.csv"

#open the file
with open(input_file, "r") as prez_file:
    #read the file line by line
    for line in prez_file:
        #print just to make sure we're reading the file okay
        # print(line, end="")

        # strip the line breaks
        line = line.strip()

        #split each line into a list
        columns = line.split(',')

        #did we split it?
        #print(columns)

        #load our presidents{} dictionary
        #num = columns[0]
        #name = columns[1]
        #presidents[num] =name
        # --- OR --- #
        presidents[columns[0]] = columns[1]

#get stuff from our dictionary
print(presidents.get('16'))
print(presidents['16'])
print(presidents.get("48"), "Not elected yet")

#loop over the dictionary
for num in presidents.keys():
    print(f"president number {num} was {presidents[num]}")
#presidents = open(input_file, "r")

#make a counter for the track number
#pres_num = 1

#for pres in presidents: 
    #one way to get rid of the extra line break is to strip it off
    
    #print(f"president {pres} is president number {pres_num}")

    #print(f"track_number {track_num} is {track}", end='')
    #another way to get rid of the extra line break is end your print with end = ''
    #pres_num += 1
#read the file line by line
# Out:
# Abraham Lincoln
# Abraham Lincoln
# None Not elected yet
# president number Presidency  was President
# president number 1 was George Washington
# president number 2 was John Adams
# president number 3 was Thomas Jefferson
# president number 4 was James Madison
# president number 5 was James Monroe
# president number 6 was John Quincy Adams
# president number 7 was Andrew Jackson
# president number 8 was Martin Van Buren
# president number 9 was William Henry Harrison
# president number 10 was John Tyler
# president number 11 was James K. Polk
# president number 12 was Zachary Taylor
# president number 13 was Millard Fillmore
# president number 14 was Franklin Pierce
# president number 15 was James Buchanan
# president number 16 was Abraham Lincoln
# president number 17 was Andrew Johnson
# president number 18 was Ulysses S. Grant
# president number 19 was Rutherford B. Hayes
# president number 20 was James A. Garfield
# president number 21 was Chester A. Arthur
# ...
