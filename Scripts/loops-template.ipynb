# %% [markdown]
# ## understanding `append`

# %%
# start fresh with new groups
jackson5 = ['jackie', 'tito', 'jermaine', 'marlon', 'michael']
destiny  = ['beyonce', 'kelly', 'michelle']
top40    = ['taylorswift', 'postmalone']

#Make a list that will be a supergroup
super = []
super.append(destiny)
super.append(jackson5)
super.append(top40)
print(len(super))
print(super)
# Out:
# 3
# [['beyonce', 'kelly', 'michelle'], ['jackie', 'tito', 'jermaine', 'marlon', 'michael'], ['taylorswift', 'postmalone']]

# %% [markdown]
# ## looping over a list

# %%
#loop over destiny as they are in super
for i in super:
    

# loop over 'destiny'
print(destiny)
for i in destiny:
    print(i)
# Out:
# ['beyonce', 'kelly', 'michelle']
# beyonce
# kelly
# michelle
# jackie
# tito
# jermaine
# marlon
# michael
# taylorswift
# postmalone

# %% [markdown]
# ## executing a nested `for` loop

# %%
#loop over destiny as they are inside super
for i in super[0]:
    print(i)

print()
# loop over jackson5 as they are inside super
for i in super[1]:
    print(i)
print()

#loop over top40 as they are inside super
for i in super[2]:
    print(i)
    print()

print("here's the nested for loop:")
print()
#make some counters
band_num = 0
total_band_size=0

#loop within a loop
for band in super:
    member_num=0
    band_num += 1 # same as doing this: band_num = band_num + 1
    for member in band:

        member_num += 1
        print(f"{member} is member {member_num} of band {band_num}")
        total_band_size += 1
        
print(f"The total number of members is {total_band_size}")
# Out:
# beyonce
# kelly
# michelle
#
# jackie
# tito
# jermaine
# marlon
# michael
#
# taylorswift
#
# postmalone
#
# here's the nested for loop:
#
# beyonce is member 1 of band 1
# kelly is member 2 of band 1
# michelle is member 3 of band 1
# jackie is member 1 of band 2
# tito is member 2 of band 2
# jermaine is member 3 of band 2
# marlon is member 4 of band 2
# michael is member 5 of band 2
# taylorswift is member 1 of band 3
# postmalone is member 2 of band 3
# The total number of members is 10

# %% [markdown]
# ### retrieve the index _and_ the value with `enumerate()`

# %%
# lots of flexibility with enumerate()
presidents = ["George Washington", "John Adams", "Thomas Jefferson", "James Madison", "James Monroe", "John Quincy Adams", "Andrew Jackson", "Martin Van Buren", "William Henry Harrison", "John Tyler", "James Knox Polk", "Zachary Taylor", "Millard Fillmore", "Franklin Pierce", "James Buchanan", "Abraham Lincoln", "Andrew Johnson", "Ulysses S. Grant", "Rutherford Birchard Hayes", "James Abram Garfield", "Chester Alan Arthur", "Grover Cleveland", "Benjamin Harrison", "Grover Cleveland", "William McKinley", "Theodore Roosevelt", "William Howard Taft", "Woodrow Wilson", "Warren Gamaliel Harding", "Calvin Coolidge", "Herbert Clark Hoover", "Franklin Delano Roosevelt", "Harry S. Truman", "Dwight David Eisenhower", "John Fitzgerald Kennedy", "Lyndon Baines Johnson", "Richard Milhous Nixon", "Gerald Rudolph Ford", "James Earl Carter Jr.", "Ronald Wilson Reagan", "George Herbert Walker Bush", "William Jefferson Clinton", "George Walker Bush", "Barack Hussein Obama", "Donald Trump", "Joe Biden"]

for num, name in enumerate(presidents):
    print(f"President number {num+1} ws {name}")
# Out:
# President number 1 ws George Washington
# President number 2 ws John Adams
# President number 3 ws Thomas Jefferson
# President number 4 ws James Madison
# President number 5 ws James Monroe
# President number 6 ws John Quincy Adams
# President number 7 ws Andrew Jackson
# President number 8 ws Martin Van Buren
# President number 9 ws William Henry Harrison
# President number 10 ws John Tyler
# President number 11 ws James Knox Polk
# President number 12 ws Zachary Taylor
# President number 13 ws Millard Fillmore
# President number 14 ws Franklin Pierce
# President number 15 ws James Buchanan
# President number 16 ws Abraham Lincoln
# President number 17 ws Andrew Johnson
# President number 18 ws Ulysses S. Grant
# President number 19 ws Rutherford Birchard Hayes
# President number 20 ws James Abram Garfield
# President number 21 ws Chester Alan Arthur
# President number 22 ws Grover Cleveland
# President number 23 ws Benjamin Harrison
# President number 24 ws Grover Cleveland
# President number 25 ws William McKinley
# President number 26 ws Theodore Roosevelt
# President number 27 ws William Howard Taft
# President number 28 ws Woodrow Wilson
# President number 29 ws Warren Gamaliel Harding
# President number 30 ws Calvin Coolidge
# President number 31 ws Herbert Clark Hoover
# President number 32 ws Franklin Delano Roosevelt
# President number 33 ws Harry S. Truman
# President number 34 ws Dwight David Eisenhower
# President number 35 ws John Fitzgerald Kennedy
# President number 36 ws Lyndon Baines Johnson
# President number 37 ws Richard Milhous Nixon
# President number 38 ws Gerald Rudolph Ford
# President number 39 ws James Earl Carter Jr.
# President number 40 ws Ronald Wilson Reagan
# President number 41 ws George Herbert Walker Bush
# President number 42 ws William Jefferson Clinton
# President number 43 ws George Walker Bush
# President number 44 ws Barack Hussein Obama
# President number 45 ws Donald Trump
# President number 46 ws Joe Biden

# %% [markdown]
# ## loop over a string

# %%
today = "Wednesday"
vowels = "aeiou"

for letter in today:
    if letter not in vowels:
        print(letter, end= '')
# Out:
# Wdnsdy
